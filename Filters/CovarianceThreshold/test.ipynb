# %%
import pandas as pd
import numpy as np

# %%
from IPython.display import Image
Image('image.png')

# %%
Image('image_1.png')

# %%
import numpy as np

# Sample data
height = [150, 160, 170, 180, 190]  # in cm
weight = [50, 60, 70, 80, 90]  # in kg
income = [30000, 40000, 50000, 60000, 70000]  # in dollars

df = pd.DataFrame({
    "Height": height,
    "Weight": weight,
    "Income": income
})
# Out:
# Covariance Matrix:
#            Height    Weight       Income
# Height     250.0     250.0     250000.0
# Weight     250.0     250.0     250000.0
# Income  250000.0  250000.0  250000000.0

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()

df_scaled = pd.DataFrame(standard_scaler.fit_transform(df), columns=df.columns)

df_scaled
# Out:
#      Height    Weight    Income
# 0 -1.414214 -1.414214 -1.414214
# 1 -0.707107 -0.707107 -0.707107
# 2  0.000000  0.000000  0.000000
# 3  0.707107  0.707107  0.707107
# 4  1.414214  1.414214  1.414214

# %%
scaled_cov = df_scaled.cov()

print(f'Covariance Matrix After Fixing Scaling', scaled_cov)
# Out:
# Covariance Matrix After Fixing Scaling         Height  Weight  Income
# Height    1.25    1.25    1.25
# Weight    1.25    1.25    1.25
# Income    1.25    1.25    1.25

# %%
# Step 3: Define threshold and remove highly correlated features
threshold = 0.8  # Example threshold
high_cov_features = set()

for i in range(len(cov_matrix.columns)):
    for j in range(i):
        if abs(cov_matrix.iloc[i, j]) > threshold:
            high_cov_features.add(cov_matrix.columns[i])

# Drop features with high covariance
df_filtered = df.drop(columns=high_cov_features)
print("High Correlated features are",high_cov_features)
print("\nFiltered Data (After Removing High Covariance Features):\n", df_filtered)
# Out:
# High Correlated features are {'Weight', 'Income'}
#
# Filtered Data (After Removing High Covariance Features):
#     Height
# 0     150
# 1     160
# 2     170
# 3     180
# 4     190

# %%
Image('image_3.png')
