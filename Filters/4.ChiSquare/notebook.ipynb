# %%
import pandas as pd
import numpy as np
from IPython.display import Image

# %%
Image("image_1.png")

# %%
# CALCULATE OR TAKE CROSS TAB BETWEEN CATEGORICAL AND TARGET VARIABLE
Image("image_2.png")

# %%
# CACULATE TOAL NO OF ROWS AND NO OF COLUMNS DATA
Image("image_3.png")

# %%
# CALCULATE EXPECTED FREQUENCY CALCULATION
Image("image_4.png")

# %%
# CALCULATE CHI SQUARE
Image("image_5.png")

# %%
# CALCULATE P VALUE FROM CHAT USING CHISQUARE
Image("image_6.png")

# %%
Image("image_7.png")

# %%
# Create a categorical dataset
data = {
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female'],
    'Purchased': ['Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No']
}

df = pd.DataFrame(data)

# %%
contigency_table = pd.crosstab(df['Gender'], df['Purchased'])
contigency_table
# Out:
# Purchased  No  Yes
# Gender
# Female      3    2
# Male        2    3

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contigency_table)

print("Chi square Static", chi2)
print("P-Value", p)
print("Degree of freedom", dof)
print("Expected Frequency", expected)
# Out:
# Chi square Static 0.0
# P-Value 1.0
# Degree of freedom 1
# Expected Frequency [[2.5 2.5]
#  [2.5 2.5]]

# %%
# Interpret the result
alpha = 0.05
if p < alpha:
    print("\nConclusion: Reject the null hypothesis - The variables are dependent.")
else:
    print("\nConclusion: Fail to reject the null hypothesis - The variables are independent.")
# Out:
# Conclusion: Fail to reject the null hypothesis - The variables are independent.
