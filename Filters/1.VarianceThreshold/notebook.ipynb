# %%
from IPython.display import Image

Image("image_1.png")

# %%
Image("image_3.png")

# %%
Image('image_2.png')

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import VarianceThreshold

data = {
    "Feature1": [1, 1, 1, 1, 1],  # No variance (constant)
    "Feature2": [0, 1, 0, 1, 1],  # Some variance
    "Feature3": [2, 2, 2, 2, 2],  # No variance (constant)
    "Feature4": [10, 11, 12, 13, 14]  # High variance
}

df = pd.DataFrame(data)

df
# Out:
#    Feature1  Feature2  Feature3  Feature4
# 0         1         0         2        10
# 1         1         1         2        11
# 2         1         0         2        12
# 3         1         1         2        13
# 4         1         1         2        14

# %%
selector = VarianceThreshold(threshold=0.1)

df_selected = selector.fit_transform(df)

selected_features = df.columns[selector.get_support()]

print("selected features are", selected_features)

print("\nFiltered Data:\n", pd.DataFrame(df_selected, columns=selected_features))
# Out:
# selected features are Index(['Feature2', 'Feature4'], dtype='object')
#
# Filtered Data:
#     Feature2  Feature4
# 0         0        10
# 1         1        11
# 2         0        12
# 3         1        13
# 4         1        14
